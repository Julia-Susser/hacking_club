# %%
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import seaborn as sns

streeteasy = pd.read_csv("https://raw.githubusercontent.com/sonnynomnom/Codecademy-Machine-Learning-Fundamentals/master/StreetEasy/manhattan.csv")

df = pd.DataFrame(streeteasy)


plt.figure(figsize = (20,10))
correlation_matrix = df.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True)

# %%
#BASICALLY x=df.drop("rent",axis=1)
x = df[['bedrooms', 'bathrooms', 'size_sqft', 'min_to_subway', 'floor', 'building_age_yrs', 'no_fee', 'has_roofdeck', 'has_washer_dryer', 'has_doorman', 'has_elevator', 'has_dishwasher', 'has_patio', 'has_gym']]

y = df[['rent']]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2, random_state=6)

# %%
lm = LinearRegression()

model = lm.fit(x_train, y_train)

y_predict= lm.predict(x_test)

# %%
plt.scatter(y_test, y_predict)
plt.plot(range(20000), range(20000))

plt.xlabel("Prices: $Y_i$")
plt.ylabel("Predicted prices: $\hat{Y}_i$")
plt.title("Actual Rent vs Predicted Rent")

plt.show()

# %%
print("Train score:")
print(lm.score(x_train, y_train))

print("Test score:")
print(lm.score(x_test, y_test))

#SAME THING IS R^2 score for Test Score
from sklearn.metrics import r2_score
print("Test score:")
r2_score(y_test, y_predict)

print(lm.coef_)
# Out:
# Train score:
# 0.7725460559817883
# Test score:
# 0.805037197535764
# Test score:
# 0.805037197535764

# %%
pd.DataFrame(
    {
        'Feature': ['bedrooms', 'bathrooms', 'size_sqft', 'min_to_subway', 'floor', 'building_age_yrs', 'no_fee', 'has_roofdeck', 'has_washer_dryer', 'has_doorman', 'has_elevator', 'has_dishwasher', 'has_patio', 'has_gym'],
        'Coefficient': lm.coef_[0]
    }
)
# Out:
#              Feature  Coefficient
# 0           bedrooms  -302.730094
# 1          bathrooms  1199.385995
# 2          size_sqft     4.799767
# 3      min_to_subway   -24.289932
# 4              floor    24.198242
# 5   building_age_yrs    -7.582725
# 6             no_fee  -140.906648
# 7       has_roofdeck    48.850174
# 8   has_washer_dryer   191.425732
# 9        has_doorman  -151.114534
# 10      has_elevator    89.408889
# 11    has_dishwasher   -57.897146
# 12         has_patio   -19.319486
# 13           has_gym   -38.923698

# %% [markdown]
# # TIME TO TRY IT BY YOURSELF (Check below for answer key if you get stuck)

# %%
df = pd.read_csv("Fish.csv")
df=df.drop(["Species"],axis=1)
#WE ARE GOING TO FIND THE WEIGHT FROM THE VARIABLES

x=df.drop(["Weight", "Species"],axis=1)
y=df["Weight"]
#DO The rest following above as a key!! Check below to see if your graph looks like mine!

# %%
#ANSWER KEY

"""df = pd.read_csv("Fish.csv")

df.head()

x=df.drop(["Weight", "Species"],axis=1)
y=df["Weight"]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2, random_state=6)


lm = LinearRegression()

model = lm.fit(x_train, y_train)

y_predict= lm.predict(x_test)

plt.scatter(y_test, y_predict)
plt.plot(y_test, y_test)

plt.xlabel("Weight: $Y_i$")
plt.ylabel("Predicted weight: $\hat{Y}_i$")
plt.title("Actual weight vs Predicted weight")

plt.show()
print("Train score:")
print(lm.score(x_train, y_train))

print("Test score:")
print(lm.score(x_test, y_test))"""
# Out:
# Train score:
# 0.8902178331908365
# Test score:
# 0.862674348504698
